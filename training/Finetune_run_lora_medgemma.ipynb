# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U transformers peft trl bitsandbytes accelerate datasets nibabel pydicom
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 93.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.6/721.6 kB 62.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 115.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 52.2 MB/s eta 0:00:00

# %%
from huggingface_hub import login

# Replace with your actual Hugging Face write token
login("hf_YOUR_TOKEN_HERE")

# %%
# !pip install -q "datasets<3.0.0"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 39.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 22.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# trl 1.3.0 requires datasets>=4.7.0, but you have datasets 2.21.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.

# %%
# !python /content/drive/MyDrive/Trauma_Lifesaver/optimized_lora_finetune.py \
    --output_dir /content/drive/MyDrive/Trauma_Lifesaver/models/medgemma-1v5-4b-it-rsna23-abd-ct-peft-lora-r16-a32-ep3-lr2e4-v1 \
    --num_epochs 3 \
    --max_samples 200
# Out:
# ...
# MedGemma 1.5 LoRA Fine-Tuning on RSNA Trauma Dataset (Optimized)
# ...
#
# Device: CUDA — NVIDIA A100-SXM4-40GB
# Bfloat16 Supported: True
#
# [1/4] Loading the dataset (jherng/rsna-2023-abdominal-trauma-detection) in streaming mode...
# ...
# Generating train split: 1510373 examples [00:01, 1282930.81 examples/s]
#       Fetching metadata for selected samples (this may take a moment)...
#       Lazy dataset initialized. Files will be downloaded on-the-fly.
#
# [2/4] Loading the model (google/medgemma-1.5-4b-it)...
#       Using Attention Implementation: sdpa
# config.json: 2.55kB [00:00, 8.26MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 90.6kB [00:00, 28.1MB/s]
# ...
# Fetching 2 files: 100% 2/2 [00:23<00:00, 11.74s/it]
# Download complete: 100% 8.60G/8.60G [00:24<00:00, 351MB/s]
# Loading weights: 100% 883/883 [00:02<00:00, 314.65it/s]
# generation_config.json: 100% 115/115 [00:00<00:00, 636kB/s]
# ...

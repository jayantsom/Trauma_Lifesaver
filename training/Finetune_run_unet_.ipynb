# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q -U segmentation-models-pytorch albumentations nibabel pydicom

# %%
from huggingface_hub import login
# Replace with your actual Hugging Face write token
login("hf_YOUR_TOKEN_HERE")

# %%
# !pip install -q "datasets<3.0.0"

# %%
# !python /content/drive/MyDrive/Trauma_Lifesaver/train_unet_segmenter.py \
    --output_dir /content/drive/MyDrive/Trauma_Lifesaver/models/unet-resnet34-rsna23-abd-ct-seg-ep10-lr1e4-v1 \
    --num_epochs 10 \
    --max_samples 1000 \
    --batch_size 4
# Out:
# ...
# U-Net (ResNet34) Fine-Tuning on RSNA Trauma Segmentation
# ...
#
# Device: cuda
#
# [1/4] Loading the dataset (jherng/rsna-2023-abdominal-trauma-detection) in streaming mode...
# ...
# Generating train split: 1510373 examples [00:01, 1222168.45 examples/s]
# /content/drive/MyDrive/Trauma_Lifesaver/train_unet_segmenter.py:226: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=0.3, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
#       Fetching metadata for selected samples (this may take a moment)...
#
# [2/4] Initializing U-Net model with ResNet34 backbone...
# config.json: 100% 156/156 [00:00<00:00, 739kB/s]
# model.safetensors: 100% 87.3M/87.3M [00:01<00:00, 63.9MB/s]
#
# [3/4] Configuring the optimizer and loss function...
#
# [4/4] Starting the training process...
#   Epochs:           10
#   Batch size:       4 (Accumulation: 4)
#   Learning rate:    0.0001
# ...
